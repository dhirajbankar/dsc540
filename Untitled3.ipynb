# %%
import pandas as pd

df = pd.read_html("https://www.nytimes.com/interactive/2020/us/coronavirus-us-cases.html")
len(df)
# Out:
# 8

# %%
for t in df:
    print(t.shape)
# Out:
# (3, 4)
# (10, 10)
# (10, 6)
# (10, 3)
# (10, 3)
# (10, 3)
# (5, 3)
# (5, 3)

# %%
df15 = df[1]
df15.head()
# Out:
#             Unnamed: 0  Totalcases  Per 100,000  Totaldeaths  Per 100,000.1  \
# 0     + Arizona  MAP »      556384         7644         9061            124
# 1  + California  MAP »     2433838         6160        26635             67
# 2   + Tennessee  MAP »      593363         8689         6962            102
# 3    + Oklahoma  MAP »      304072         7684         2547             64
# 4    + Arkansas  MAP »      233475         7737         3749            124
#
#    Daily avg.in last7 days  Per 100,000.2  Daily avg.in last7 days.1  \
# 0                   8842.1          121.5                       90.6
# 1                  38086.4           96.4                      336.0
# 2                   6294.9           92.2                       73.0
# 3                   3561.9           90.0                       25.3
# 4                   2656.9           88.0                       38.1
#
#    Per 100,000.3 Weekly cases per capita  Fewer \tMore
# ...

# %%
df15.tail()
# Out:
#                Unnamed: 0  Totalcases  Per 100,000  Totaldeaths  \
# 5         + Kansas  MAP »      230352         7907         2879
# 6           + Utah  MAP »      283473         8842         1301
# 7  + West Virginia  MAP »       91058         5081         1376
# 8   + Rhode Island  MAP »       87949         8302         1777
# 9        + Georgia  MAP »      667705         6289        10616
#
#    Per 100,000.1  Daily avg.in last7 days  Per 100,000.2  \
# 5             99                   2454.1           84.2
# 6             41                   2657.0           82.9
# 7             77                   1478.3           82.5
# 8            168                    840.4           79.3
# 9            100                   8161.6           76.9
#
#    Daily avg.in last7 days.1  Per 100,000.3  \
# 5                       53.1            1.8
# 6                       12.4            0.4
# 7                       17.4            1.0
# 8                       10.4            1.0
# ...

# %%
df15.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-a26b9ca39a89> in <module>
# ----> 1 df15.shape()
#
# TypeError: 'tuple' object is not callable
